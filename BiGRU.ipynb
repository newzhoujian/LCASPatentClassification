# %%
import pickle
import tensorflow as tf
import keras
import keras.backend as K
from keras.layers import *
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.models import save_model
from keras.models import load_model
import os

X = pickle.load(open("../data/X_data_random.pkl","rb"))
y = pickle.load(open("../data/y_data_random.pkl","rb"))
word2id, id2word = pickle.load(open("../data/word2idandid2word.pkl","rb"))
label2id, id2label = pickle.load(open("../data/label2idandid2label.pkl","rb"))
word2vec_matrix = pickle.load(open("../data/word2vec_matrix.pkl","rb"))


index1 = 50000
index2 = 70000
X_train, X_val, X_test = X[:index1], X[index1:index2], X[index2:]
y_train, y_val, y_test = y[:index1], y[index1:index2], y[index2:]

os.environ['CUDA_VISIBLE_DEVICES'] = "0"

padding_len = 200

with tf.device('/gpu:0'):
    model_input = Input(shape=(padding_len,))
    
    wordembed = Embedding(len(word2vec_matrix), 300, weights=[word2vec_matrix], input_length=padding_len, trainable=False)(model_input)
    sen2vec = Bidirectional(GRU(300, activation='tanh', return_sequences=False))(wordembed)
    
    model_output = Dense(len(label2id), activation='softmax')(sen2vec)
    model = Model(inputs=model_input, outputs=model_output)
    model.summary()
    checkpoint = ModelCheckpoint("../PCmodel/BiGRU.h5", monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
    model.fit(X_train, y_train, batch_size=200, epochs=20, validation_data=(X_val, y_val), callbacks=[checkpoint])
    model.save("../PCmodel/BiGRU.h5")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 200, 300)          68857800
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 600)               1081800
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 4808
# =================================================================
# Total params: 69,944,408
# Trainable params: 1,086,608
# Non-trainable params: 68,857,800
# _________________________________________________________________
# Train on 50000 samples, validate on 20000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 113s 2ms/step - loss: 1.0683 - categorical_accuracy: 0.6177 - val_loss: 0.7506 - val_categorical_accuracy: 0.7369
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.73685, saving model to ../PCmodel/BiGRU.h5
# Epoch 2/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.7021 - categorical_accuracy: 0.7547 - val_loss: 0.6596 - val_categorical_accuracy: 0.7691
#
# Epoch 00002: val_categorical_accuracy improved from 0.73685 to 0.76905, saving model to ../PCmodel/BiGRU.h5
# Epoch 3/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.6379 - categorical_accuracy: 0.7746 - val_loss: 0.6255 - val_categorical_accuracy: 0.7781
#
# Epoch 00003: val_categorical_accuracy improved from 0.76905 to 0.77815, saving model to ../PCmodel/BiGRU.h5
# Epoch 4/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.5929 - categorical_accuracy: 0.7903 - val_loss: 0.5859 - val_categorical_accuracy: 0.7917
#
# Epoch 00004: val_categorical_accuracy improved from 0.77815 to 0.79170, saving model to ../PCmodel/BiGRU.h5
# Epoch 5/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.5604 - categorical_accuracy: 0.8006 - val_loss: 0.5885 - val_categorical_accuracy: 0.7904
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.79170
# Epoch 6/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.5332 - categorical_accuracy: 0.8101 - val_loss: 0.5554 - val_categorical_accuracy: 0.8005
#
# Epoch 00006: val_categorical_accuracy improved from 0.79170 to 0.80045, saving model to ../PCmodel/BiGRU.h5
# Epoch 7/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.5052 - categorical_accuracy: 0.8200 - val_loss: 0.5473 - val_categorical_accuracy: 0.8051
#
# Epoch 00007: val_categorical_accuracy improved from 0.80045 to 0.80510, saving model to ../PCmodel/BiGRU.h5
# Epoch 8/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.4790 - categorical_accuracy: 0.8285 - val_loss: 0.5378 - val_categorical_accuracy: 0.8068
#
# Epoch 00008: val_categorical_accuracy improved from 0.80510 to 0.80675, saving model to ../PCmodel/BiGRU.h5
# Epoch 9/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.4564 - categorical_accuracy: 0.8369 - val_loss: 0.5407 - val_categorical_accuracy: 0.8066
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.80675
# Epoch 10/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.4326 - categorical_accuracy: 0.8436 - val_loss: 0.5401 - val_categorical_accuracy: 0.8103
#
# Epoch 00010: val_categorical_accuracy improved from 0.80675 to 0.81030, saving model to ../PCmodel/BiGRU.h5
# Epoch 11/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.4159 - categorical_accuracy: 0.8519 - val_loss: 0.5413 - val_categorical_accuracy: 0.8071
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.81030
# Epoch 12/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.3876 - categorical_accuracy: 0.8622 - val_loss: 0.5369 - val_categorical_accuracy: 0.8123
#
# Epoch 00012: val_categorical_accuracy improved from 0.81030 to 0.81225, saving model to ../PCmodel/BiGRU.h5
# Epoch 13/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.3922 - categorical_accuracy: 0.8606 - val_loss: 0.6152 - val_categorical_accuracy: 0.7928
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.81225
# Epoch 14/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.3837 - categorical_accuracy: 0.8612 - val_loss: 0.5636 - val_categorical_accuracy: 0.8096
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.81225
# Epoch 15/20
# 50000/50000 [==============================] - 116s 2ms/step - loss: 0.3504 - categorical_accuracy: 0.8745 - val_loss: 0.5691 - val_categorical_accuracy: 0.8100
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.81225
# Epoch 16/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.3206 - categorical_accuracy: 0.8862 - val_loss: 0.5601 - val_categorical_accuracy: 0.8162
#
# Epoch 00016: val_categorical_accuracy improved from 0.81225 to 0.81625, saving model to ../PCmodel/BiGRU.h5
# Epoch 17/20
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.2935 - categorical_accuracy: 0.8946 - val_loss: 0.5691 - val_categorical_accuracy: 0.8156
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.81625
# Epoch 18/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.2664 - categorical_accuracy: 0.9054 - val_loss: 0.6193 - val_categorical_accuracy: 0.8119
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.81625
# Epoch 19/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.2400 - categorical_accuracy: 0.9165 - val_loss: 0.6473 - val_categorical_accuracy: 0.8117
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.81625
# Epoch 20/20
# 50000/50000 [==============================] - 111s 2ms/step - loss: 0.2135 - categorical_accuracy: 0.9256 - val_loss: 0.6494 - val_categorical_accuracy: 0.8118
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.81625

# %%
y_pred = model.predict(X_test)
y1 = [np.argmax(i) for i in y_test]
y2 = [np.argmax(i) for i in y_pred]

from sklearn import metrics

print('precision:')
print(metrics.precision_score(y1,y2,average='micro'))
print(metrics.precision_score(y1,y2,average='macro'))

print('recall:')
print(metrics.recall_score(y1,y2,average='micro'))
print(metrics.recall_score(y1,y2,average='macro'))

print('f1:')
print(metrics.f1_score(y1,y2,average='micro'))
print(metrics.f1_score(y1,y2,average='macro'))
# Out:
# precision:
# 0.8098
# 0.8094986351558182
# recall:
# 0.8098
# 0.8093551947541858
# f1:
# 0.8097999999999999
# 0.8090918180994054
