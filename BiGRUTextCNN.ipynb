# %%
import pickle
import tensorflow as tf
import keras
import keras.backend as K
from keras.layers import *
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.models import save_model
from keras.models import load_model
import os

X = pickle.load(open("../data/X_data_random.pkl","rb"))
y = pickle.load(open("../data/y_data_random.pkl","rb"))
word2id, id2word = pickle.load(open("../data/word2idandid2word.pkl","rb"))
label2id, id2label = pickle.load(open("../data/label2idandid2label.pkl","rb"))
word2vec_matrix = pickle.load(open("../data/word2vec_matrix.pkl","rb"))


index1 = 50000
index2 = 70000
X_train, X_val, X_test = X[:index1], X[index1:index2], X[index2:]
y_train, y_val, y_test = y[:index1], y[index1:index2], y[index2:]

os.environ['CUDA_VISIBLE_DEVICES'] = "0"

padding_len = 200

with tf.device('/gpu:0'):
    model_input = Input(shape=(padding_len,))
    
    wordembed = Embedding(len(word2vec_matrix), 300, weights=[word2vec_matrix], input_length=padding_len, trainable=False)(model_input)
    sen2vec = Bidirectional(GRU(300, activation='tanh', return_sequences=True))(wordembed)
    
    convs = []
    filter_size = [2, 3, 4, 5]
    for i in filter_size:
        conv_layer = Conv1D(filters=128, kernel_size=i, activation='relu')(sen2vec)
        pool_layer = MaxPooling1D(200-i+1, 1)(conv_layer)
        pool_layer = Flatten()(pool_layer)
        convs.append(pool_layer)
    sen2vec_conv = concatenate(convs, axis=1)
    sen2vec_conv = Dropout(0.5)(sen2vec_conv)
    model_output = Dense(len(label2id), activation='softmax')(sen2vec_conv)
    model = Model(inputs=model_input, outputs=model_output)
    model.summary()
    checkpoint = ModelCheckpoint("../PCmodel/BiGRUTextCNN.h5", monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
    model.fit(X_train, y_train, batch_size=200, epochs=20, validation_data=(X_val, y_val), callbacks=[checkpoint])
    model.save("../PCmodel/BiGRUTextCNN.h5")
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /data/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /data/miniconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 300)     68857800    input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 200, 600)     1081800     embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 199, 128)     153728      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 198, 128)     230528      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 197, 128)     307328      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 196, 128)     384128      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 1, 128)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1, 128)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 1, 128)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 1, 128)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 128)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 128)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 128)          0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            4104        dropout_1[0][0]
# ==================================================================================================
# Total params: 71,019,416
# Trainable params: 2,161,616
# Non-trainable params: 68,857,800
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /data/miniconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 20000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.8024 - categorical_accuracy: 0.7184 - val_loss: 0.6506 - val_categorical_accuracy: 0.7711
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.77115, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 2/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.6437 - categorical_accuracy: 0.7729 - val_loss: 0.6119 - val_categorical_accuracy: 0.7810
#
# Epoch 00002: val_categorical_accuracy improved from 0.77115 to 0.78095, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 3/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.6009 - categorical_accuracy: 0.7891 - val_loss: 0.5755 - val_categorical_accuracy: 0.7950
#
# Epoch 00003: val_categorical_accuracy improved from 0.78095 to 0.79500, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 4/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.5640 - categorical_accuracy: 0.8008 - val_loss: 0.5737 - val_categorical_accuracy: 0.7887
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.79500
# Epoch 5/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.5299 - categorical_accuracy: 0.8132 - val_loss: 0.5487 - val_categorical_accuracy: 0.8061
#
# Epoch 00005: val_categorical_accuracy improved from 0.79500 to 0.80615, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 6/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.5009 - categorical_accuracy: 0.8213 - val_loss: 0.5227 - val_categorical_accuracy: 0.8130
#
# Epoch 00006: val_categorical_accuracy improved from 0.80615 to 0.81305, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 7/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.4701 - categorical_accuracy: 0.8339 - val_loss: 0.5336 - val_categorical_accuracy: 0.8121
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.81305
# Epoch 8/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.4375 - categorical_accuracy: 0.8426 - val_loss: 0.5300 - val_categorical_accuracy: 0.8150
#
# Epoch 00008: val_categorical_accuracy improved from 0.81305 to 0.81500, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 9/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.4096 - categorical_accuracy: 0.8533 - val_loss: 0.5187 - val_categorical_accuracy: 0.8213
#
# Epoch 00009: val_categorical_accuracy improved from 0.81500 to 0.82135, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 10/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.3730 - categorical_accuracy: 0.8660 - val_loss: 0.5218 - val_categorical_accuracy: 0.8219
#
# Epoch 00010: val_categorical_accuracy improved from 0.82135 to 0.82185, saving model to ../PCmodel/BiGRUTextCNN.h5
# Epoch 11/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.3422 - categorical_accuracy: 0.8779 - val_loss: 0.5291 - val_categorical_accuracy: 0.8218
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.82185
# Epoch 12/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.3093 - categorical_accuracy: 0.8878 - val_loss: 0.5700 - val_categorical_accuracy: 0.8210
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.82185
# Epoch 13/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.2693 - categorical_accuracy: 0.9034 - val_loss: 0.5868 - val_categorical_accuracy: 0.8179
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.82185
# Epoch 14/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.2371 - categorical_accuracy: 0.9150 - val_loss: 0.5867 - val_categorical_accuracy: 0.8198
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.82185
# Epoch 15/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.2038 - categorical_accuracy: 0.9268 - val_loss: 0.6279 - val_categorical_accuracy: 0.8213
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.82185
# Epoch 16/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.1719 - categorical_accuracy: 0.9377 - val_loss: 0.6622 - val_categorical_accuracy: 0.8173
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.82185
# Epoch 17/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.1427 - categorical_accuracy: 0.9489 - val_loss: 0.7619 - val_categorical_accuracy: 0.8190
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.82185
# Epoch 18/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.1263 - categorical_accuracy: 0.9552 - val_loss: 0.7914 - val_categorical_accuracy: 0.8178
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.82185
# Epoch 19/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.1004 - categorical_accuracy: 0.9641 - val_loss: 0.8163 - val_categorical_accuracy: 0.8171
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.82185
# Epoch 20/20
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.0895 - categorical_accuracy: 0.9674 - val_loss: 0.8209 - val_categorical_accuracy: 0.8179
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.82185

# %%
y_pred = model.predict(X_test)
y1 = [np.argmax(i) for i in y_test]
y2 = [np.argmax(i) for i in y_pred]

from sklearn import metrics

print('precision:')
print(metrics.precision_score(y1,y2,average='micro'))
print(metrics.precision_score(y1,y2,average='macro'))

print('recall:')
print(metrics.recall_score(y1,y2,average='micro'))
print(metrics.recall_score(y1,y2,average='macro'))

print('f1:')
print(metrics.f1_score(y1,y2,average='micro'))
print(metrics.f1_score(y1,y2,average='macro'))
# Out:
# precision:
# 0.8163
# 0.816481022459364
# recall:
# 0.8163
# 0.8151069193585587
# f1:
# 0.8162999999999999
# 0.81539215749308
