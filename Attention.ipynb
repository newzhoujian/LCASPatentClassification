# %%
import pickle
import tensorflow as tf
import keras
import keras.backend as K
from keras.layers import *
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.models import save_model
from keras.models import load_model
import os

X = pickle.load(open("../data/X_data_random.pkl","rb"))
y = pickle.load(open("../data/y_data_random.pkl","rb"))
word2id, id2word = pickle.load(open("../data/word2idandid2word.pkl","rb"))
label2id, id2label = pickle.load(open("../data/label2idandid2label.pkl","rb"))
word2vec_matrix = pickle.load(open("../data/word2vec_matrix.pkl","rb"))


index1 = 50000
index2 = 70000
X_train, X_val, X_test = X[:index1], X[index1:index2], X[index2:]
y_train, y_val, y_test = y[:index1], y[index1:index2], y[index2:]

os.environ['CUDA_VISIBLE_DEVICES'] = "0"

padding_len = 200

with tf.device('/gpu:0'):
    model_input = Input(shape=(padding_len,))
    
    wordembed = Embedding(len(word2vec_matrix), 300, weights=[word2vec_matrix], input_length=padding_len, trainable=False)(model_input)
    
    attention = Dense(1, activation='tanh')(wordembed)
    attention = Flatten()(attention)
    attention = Activation('softmax')(attention)
    attention = RepeatVector(300)(attention)
    attention = Permute([2, 1])(attention)
    sent_representation = Multiply()([wordembed, attention])
    sent_representation = Flatten()(sent_representation)
    sent_representation = Dense(600, activation='tanh')(sent_representation)
    sen2vec_conv = Dropout(0.5)(sent_representation)
    model_output = Dense(len(label2id), activation='softmax')(sen2vec_conv)
    model = Model(inputs=model_input, outputs=model_output)
    model.summary()
    checkpoint = ModelCheckpoint("../PCmodel/Attention.h5", monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
    model.fit(X_train, y_train, batch_size=200, epochs=20, validation_data=(X_val, y_val), callbacks=[checkpoint])
    model.save("../PCmodel/Attention.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 200, 300)     68857800    input_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 200, 1)       301         embedding_4[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 200)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200)          0           flatten_4[0][0]
# __________________________________________________________________________________________________
# repeat_vector_4 (RepeatVector)  (None, 300, 200)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 200, 300)     0           repeat_vector_4[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 200, 300)     0           embedding_4[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 60000)        0           multiply_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 600)          36000600    flatten_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 600)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 8)            4808        dropout_3[0][0]
# ==================================================================================================
# Total params: 104,863,509
# Trainable params: 36,005,709
# Non-trainable params: 68,857,800
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /data/miniconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 20000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 9s 177us/step - loss: 1.3315 - categorical_accuracy: 0.5611 - val_loss: 0.9662 - val_categorical_accuracy: 0.6676
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.66765, saving model to ../PCmodel/Attention.h5
# Epoch 2/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.8643 - categorical_accuracy: 0.7016 - val_loss: 0.8361 - val_categorical_accuracy: 0.7060
#
# Epoch 00002: val_categorical_accuracy improved from 0.66765 to 0.70595, saving model to ../PCmodel/Attention.h5
# Epoch 3/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.7310 - categorical_accuracy: 0.7485 - val_loss: 0.7818 - val_categorical_accuracy: 0.7254
#
# Epoch 00003: val_categorical_accuracy improved from 0.70595 to 0.72545, saving model to ../PCmodel/Attention.h5
# Epoch 4/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.6327 - categorical_accuracy: 0.7845 - val_loss: 0.7617 - val_categorical_accuracy: 0.7303
#
# Epoch 00004: val_categorical_accuracy improved from 0.72545 to 0.73025, saving model to ../PCmodel/Attention.h5
# Epoch 5/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.5469 - categorical_accuracy: 0.8185 - val_loss: 0.7591 - val_categorical_accuracy: 0.7366
#
# Epoch 00005: val_categorical_accuracy improved from 0.73025 to 0.73660, saving model to ../PCmodel/Attention.h5
# Epoch 6/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.4672 - categorical_accuracy: 0.8496 - val_loss: 0.7681 - val_categorical_accuracy: 0.7355
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.73660
# Epoch 7/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.3927 - categorical_accuracy: 0.8799 - val_loss: 0.7850 - val_categorical_accuracy: 0.7324
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.73660
# Epoch 8/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.3231 - categorical_accuracy: 0.9076 - val_loss: 0.8151 - val_categorical_accuracy: 0.7257
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.73660
# Epoch 9/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.2626 - categorical_accuracy: 0.9304 - val_loss: 0.8503 - val_categorical_accuracy: 0.7183
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.73660
# Epoch 10/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.2087 - categorical_accuracy: 0.9506 - val_loss: 0.8916 - val_categorical_accuracy: 0.7188
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.73660
# Epoch 11/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.1643 - categorical_accuracy: 0.9663 - val_loss: 0.9337 - val_categorical_accuracy: 0.7163
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.73660
# Epoch 12/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.1267 - categorical_accuracy: 0.9796 - val_loss: 0.9838 - val_categorical_accuracy: 0.7097
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.73660
# Epoch 13/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.0973 - categorical_accuracy: 0.9882 - val_loss: 1.0310 - val_categorical_accuracy: 0.7088
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.73660
# Epoch 14/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.0753 - categorical_accuracy: 0.9941 - val_loss: 1.0819 - val_categorical_accuracy: 0.7068
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.73660
# Epoch 15/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.0574 - categorical_accuracy: 0.9970 - val_loss: 1.1379 - val_categorical_accuracy: 0.7049
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.73660
# Epoch 16/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.0443 - categorical_accuracy: 0.9985 - val_loss: 1.1770 - val_categorical_accuracy: 0.7060
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.73660
# Epoch 17/20
# 50000/50000 [==============================] - 7s 142us/step - loss: 0.0346 - categorical_accuracy: 0.9992 - val_loss: 1.2220 - val_categorical_accuracy: 0.7046
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.73660
# Epoch 18/20
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.0274 - categorical_accuracy: 0.9997 - val_loss: 1.2670 - val_categorical_accuracy: 0.7046
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.73660
# Epoch 19/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.0223 - categorical_accuracy: 0.9998 - val_loss: 1.3159 - val_categorical_accuracy: 0.7035
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.73660
# Epoch 20/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.0183 - categorical_accuracy: 0.9998 - val_loss: 1.3537 - val_categorical_accuracy: 0.7034
# Epoch 00020: val_categorical_accuracy did not improve from 0.73660

# %%
y_pred = model.predict(X_test)
y1 = [np.argmax(i) for i in y_test]
y2 = [np.argmax(i) for i in y_pred]

from sklearn import metrics

print('precision:')
print(metrics.precision_score(y1,y2,average='micro'))
print(metrics.precision_score(y1,y2,average='macro'))

print('recall:')
print(metrics.recall_score(y1,y2,average='micro'))
print(metrics.recall_score(y1,y2,average='macro'))

print('f1:')
print(metrics.f1_score(y1,y2,average='micro'))
print(metrics.f1_score(y1,y2,average='macro'))
# Out:
# precision:
# 0.692
# 0.6935348441699676
# recall:
# 0.692
# 0.6907780884880921
# f1:
# 0.692
# 0.691878529214893
